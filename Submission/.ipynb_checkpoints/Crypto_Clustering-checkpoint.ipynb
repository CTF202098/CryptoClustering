# %%
# this cell done following along in class
# Import the required modules
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import hvplot.pandas

# Machine Learning
from sklearn.cluster import KMeans, AgglomerativeClustering, Birch
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# suppress warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b1488b3f-cb03-4d7a-a8e0-30735601d89a" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# this cell done following along in class
df_market_data.columns
# Out:
# Index(['price_change_percentage_24h', 'price_change_percentage_7d',
#        'price_change_percentage_14d', 'price_change_percentage_30d',
#        'price_change_percentage_60d', 'price_change_percentage_200d',
#        'price_change_percentage_1y'],
#       dtype='object')

# %%
# this cell done following along in class
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
# NUMERIC
num_cols = ['price_change_percentage_24h', 'price_change_percentage_7d',
       'price_change_percentage_14d', 'price_change_percentage_30d',
       'price_change_percentage_60d', 'price_change_percentage_200d',
       'price_change_percentage_1y']

# Initalize and Fit the Scaler
ss = StandardScaler()
ss.fit(df_market_data.loc[:, num_cols])

# Transform the Data
df_scaled = pd.DataFrame(ss.transform(df_market_data.loc[:, num_cols]), columns=num_cols, index=df_market_data.index) # use coin_id as index
df_scaled.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                             0.508529                    0.493193
# ethereum                            0.185446                    0.934445
# tether                              0.021774                   -0.706337
# ripple                             -0.040764                   -0.810928
# bitcoin-cash                        1.193036                    2.000959
# binancecoin                         0.891871                    1.327295
# chainlink                           0.011397                    2.572251
# cardano                             0.102530                    1.508001
# litecoin                            0.077497                    0.334297
# bitcoin-cash-sv                     0.448952                   -0.190684
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# this cell done following along in class
# Can this even be clustered?
tsne = TSNE(random_state=42)
df_tsne = pd.DataFrame(tsne.fit_transform(df_scaled.loc[:, num_cols])) # fit UNSCALED data

# Plot the clusters
plt.scatter(df_tsne[0], df_tsne[1])
plt.title("TSNE on UNSCALED Data")
plt.show()

# %%
# this cell done following along in class
# Can this even be clustered?
tsne = TSNE(random_state=42)
df_tsne = pd.DataFrame(tsne.fit_transform(df_scaled)) # fit SCALED data

# Plot the clusters
plt.scatter(df_tsne[0], df_tsne[1])
plt.title("TSNE on SCALED Data")
plt.show()

# %%
# scaled data better
# no obvious clusters

# %%
# this cell done following along in class

# Correlations
corrs = df_scaled.corr()
corrs
# Out:
#                               price_change_percentage_24h  \
# price_change_percentage_24h                      1.000000
# price_change_percentage_7d                       0.169659
# price_change_percentage_14d                      0.279682
# price_change_percentage_30d                      0.292563
# price_change_percentage_60d                      0.136974
# price_change_percentage_200d                    -0.541190
# price_change_percentage_1y                      -0.750630
#
#                               price_change_percentage_7d  \
# price_change_percentage_24h                     0.169659
# price_change_percentage_7d                      1.000000
# price_change_percentage_14d                     0.538294
# price_change_percentage_30d                     0.056899
# price_change_percentage_60d                    -0.145099
# price_change_percentage_200d                   -0.052533
# price_change_percentage_1y                     -0.038424
#
# ...

# %%
# this cell done following along in class
sns.heatmap(corrs)
plt.show()

# %%
# afflicted with multi-colinearity

# %%
# this cell done following along in class
# Define your "X" - features to predict
X = df_scaled

# %%
# this cell done following along in class
# Create a a list to store inertia values and the values of k
inertia = []
s_scores = []
vrc_scores = []

k = list(range(2, 10))

# LOOP 
for i in k:
    # Fit the Model
    k_model = KMeans(n_clusters=i, random_state=1)
    k_model.fit(X)
    inertia.append(k_model.inertia_)

    # Silhoutte Score
    preds = k_model.predict(X)
    s_score = silhouette_score(X, preds)
    s_scores.append(s_score)

    # Variance Ratio Criterion
    vrc_score = calinski_harabasz_score(X, preds)
    vrc_scores.append(vrc_score)

# Define a DataFrame to hold the values for k and the corresponding inertia
metrics = {"k": k, "inertia": inertia, "s_score": s_scores, "vrc_scores": vrc_scores}
df_metrics = pd.DataFrame(metrics)

# Review the DataFrame
df_metrics.head(10)
# Out:
#    k     inertia   s_score  vrc_scores
# 0  2  212.123342  0.690885   13.766470
# 1  3  165.136752  0.260810   14.021117
# 2  4   79.022435  0.314482   32.459853
# 3  5   66.413051  0.323913   29.892958
# 4  6   61.634088  0.251616   25.595599
# 5  7   46.074467  0.258868   29.631263
# 6  8   43.392694  0.252185   26.466078
# 7  9   32.913223  0.260185   30.879599

# %%
plt.plot(df_metrics.k, df_metrics.inertia)
plt.show()

# %%
# The best value for k is 4

# %%
# This cell modified from in class activity 19.2.5
# Make a copy
df_sub = X.copy()
k = 4

# CHANGE THIS DEPENDING ON YOUR OPTIMAL k
model = KMeans(n_clusters=k, random_state=1)

# Fit the model
model.fit(X)

# Make predictions
preds = model.predict(X)

# Add a class column with the labels to the df DataFrame
df_sub['clusters'] = preds

df_sub.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
df_sub.index
# Out:
# Index(['bitcoin', 'ethereum', 'tether', 'ripple', 'bitcoin-cash',
#        'binancecoin', 'chainlink', 'cardano', 'litecoin', 'bitcoin-cash-sv',
#        'crypto-com-chain', 'usd-coin', 'eos', 'monero', 'tron', 'tezos', 'okb',
#        'stellar', 'cosmos', 'cdai', 'neo', 'wrapped-bitcoin', 'leo-token',
#        'huobi-token', 'nem', 'binance-usd', 'iota', 'vechain', 'zcash',
#        'theta-token', 'dash', 'ethereum-classic', 'ethlend', 'maker', 'havven',
#        'omisego', 'celsius-degree-token', 'ontology', 'ftx-token', 'true-usd',
#        'digibyte'],
#       dtype='object', name='coin_id')

# %%
# Per XPert AI, this import is necessary for hover_cols
# import plotly.express as px

# %%
# This cell modified from in class activity 19.2.5
# Can this even be clustered?
tsne = TSNE(random_state=42)
df_tsne = pd.DataFrame(tsne.fit_transform(df_scaled)) # fit SCALED data first

# Begin lines modified from XPert AI
# Add the cluster labels to the DataFrame
df_tsne['clusters'] = df_sub.clusters

# Plot the clusters
plt.scatter(df_tsne[0], df_tsne[1], c=df_sub['clusters'], cmap='viridis') #could not get hover_cols to work, even after using XPert AI suggestion to import plotly.express as px and run everything through that instead of plt. PathCollection.set() got an unexpected keyword argument 'hover_cols'

# Add Labels/Title
plt.ylabel("price_change_percentage_24h", fontfamily="Arial", fontsize=12)
plt.xlabel("price_change_percentage_7d", fontfamily="Arial", fontsize=12)
plt.title("TSNE Clusters on Scaled Data", fontweight="bold", fontsize=16, fontfamily="Arial")
plt.show()

# %%
# Using fewer features causes the clusters to shift position.
